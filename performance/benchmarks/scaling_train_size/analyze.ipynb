# %% [markdown]
# # scaling_train_size — analysis
#
# Loads `results/summary.parquet` produced by `run.py` and plots how
# loss, held-out energy error, and wall time scale with the number of
# training orbits.
#
# Re-run `python run.py` whenever the sweep grid changes; this notebook
# should never train.

# %%
training_steps = 5_000 # 20_000
n_layers = 10 #10

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['font.size'] = 14
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 18 
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['xtick.major.width'] = 1.5
plt.rcParams['ytick.major.width'] = 1.5
plt.rcParams['ytick.right'] = True
plt.rcParams['xtick.top'] = True
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'STIXGeneral'
plt.rcParams['xtick.minor.visible'] = True
plt.rcParams['ytick.minor.visible'] = True


df = pd.read_parquet(Path('results') / 'summary.parquet')
df = df[df['training.steps'] == training_steps]
df = df[df['model.n_layers'] == n_layers]
df.head()
# Out:
#     data.omega  data.n_orbits  data.n_steps data.r_bounds      potential.name  \
# 39         1.5              8            32  [0.15, 0.75]  MWPotential2014_1D
# 42         1.5              8           128  [0.15, 0.75]  MWPotential2014_1D
# 44         1.5              8           512  [0.15, 0.75]  MWPotential2014_1D
# 47         1.5              8          2056  [0.15, 0.75]  MWPotential2014_1D
# 50         1.5             32            32  [0.15, 0.75]  MWPotential2014_1D
#
#                 model.class  model.input_dim  model.n_layers  \
# 39  HamiltonianMappingModel                2              10
# 42  HamiltonianMappingModel                2              10
# 44  HamiltonianMappingModel                2              10
# 47  HamiltonianMappingModel                2              10
# 50  HamiltonianMappingModel                2              10
#
#           model.layer_class model.conditioner.class  ...  git_sha  git_dirty  \
# 39  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 42  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 44  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 47  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 50  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
#
#    hostname                                       platform python_version  \
# 39     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 42     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 44     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 47     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 50     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
#
#    torch_version gpu_name  cuda_version      run_id  model.n_steps
# 39   2.3.1+cu121     None          None  1e7632217f           16.0
# 42   2.3.1+cu121     None          None  0df58eb77a           16.0
# 44   2.3.1+cu121     None          None  72937661eb           16.0
# 47   2.3.1+cu121     None          None  f5fea4b877           16.0
# 50   2.3.1+cu121     None          None  901abbfeb5           16.0
#
# [5 rows x 54 columns]

# %%
# df = df[df['training.steps'] == 200]
df
# Out:
#     data.omega  data.n_orbits  data.n_steps data.r_bounds      potential.name  \
# 39         1.5              8            32  [0.15, 0.75]  MWPotential2014_1D
# 42         1.5              8           128  [0.15, 0.75]  MWPotential2014_1D
# 44         1.5              8           512  [0.15, 0.75]  MWPotential2014_1D
# 47         1.5              8          2056  [0.15, 0.75]  MWPotential2014_1D
# 50         1.5             32            32  [0.15, 0.75]  MWPotential2014_1D
# 51         1.5             32           128  [0.15, 0.75]  MWPotential2014_1D
# 53         1.5             32           512  [0.15, 0.75]  MWPotential2014_1D
# 57         1.5             32          2056  [0.15, 0.75]  MWPotential2014_1D
# 58         1.5            128            32  [0.15, 0.75]  MWPotential2014_1D
# 59         1.5            128           128  [0.15, 0.75]  MWPotential2014_1D
# 61         1.5            128           512  [0.15, 0.75]  MWPotential2014_1D
# 65         1.5            128          2056  [0.15, 0.75]  MWPotential2014_1D
# 66         1.5            512            32  [0.15, 0.75]  MWPotential2014_1D
# 67         1.5            512           128  [0.15, 0.75]  MWPotential2014_1D
# 68         1.5            512           512  [0.15, 0.75]  MWPotential2014_1D
# 70         1.5            512          2056  [0.15, 0.75]  MWPotential2014_1D
#
#                 model.class  model.input_dim  model.n_layers  \
# 39  HamiltonianMappingModel                2              10
# 42  HamiltonianMappingModel                2              10
# 44  HamiltonianMappingModel                2              10
# 47  HamiltonianMappingModel                2              10
# 50  HamiltonianMappingModel                2              10
# 51  HamiltonianMappingModel                2              10
# 53  HamiltonianMappingModel                2              10
# 57  HamiltonianMappingModel                2              10
# 58  HamiltonianMappingModel                2              10
# 59  HamiltonianMappingModel                2              10
# 61  HamiltonianMappingModel                2              10
# 65  HamiltonianMappingModel                2              10
# 66  HamiltonianMappingModel                2              10
# 67  HamiltonianMappingModel                2              10
# 68  HamiltonianMappingModel                2              10
# 70  HamiltonianMappingModel                2              10
#
#           model.layer_class model.conditioner.class  ...  git_sha  git_dirty  \
# 39  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 42  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 44  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 47  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 50  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 51  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 53  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 57  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 58  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 59  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 61  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 65  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 66  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 67  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 68  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
# 70  SymplecticCouplingLayer     SimpleNNConditioner  ...  715faf9       True
#
#    hostname                                       platform python_version  \
# 39     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 42     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 44     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 47     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 50     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 51     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 53     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 57     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 58     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 59     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 61     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 65     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 66     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 67     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 68     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
# 70     geir  Linux-6.8.0-110-generic-x86_64-with-glibc2.39         3.12.8
#
#    torch_version gpu_name  cuda_version      run_id  model.n_steps
# 39   2.3.1+cu121     None          None  1e7632217f           16.0
# 42   2.3.1+cu121     None          None  0df58eb77a           16.0
# 44   2.3.1+cu121     None          None  72937661eb           16.0
# 47   2.3.1+cu121     None          None  f5fea4b877           16.0
# 50   2.3.1+cu121     None          None  901abbfeb5           16.0
# 51   2.3.1+cu121     None          None  7e76a3d78e           16.0
# 53   2.3.1+cu121     None          None  903e19dbab           16.0
# 57   2.3.1+cu121     None          None  8f7052a4f4           16.0
# 58   2.3.1+cu121     None          None  060312f96a           16.0
# 59   2.3.1+cu121     None          None  49057a16d4           16.0
# 61   2.3.1+cu121     None          None  fd3e999e80           16.0
# 65   2.3.1+cu121     None          None  576b6bba4d           16.0
# 66   2.3.1+cu121     None          None  de3f36156e           16.0
# 67   2.3.1+cu121     None          None  7b2c5c7470           16.0
# 68   2.3.1+cu121     None          None  2a47edcaab           16.0
# 70   2.3.1+cu121     None          None  34ff959433           16.0
#
# [16 rows x 54 columns]

# %%
# norbits = 'data.n_orbits'
# agg_norbits = df.groupby(norbits).agg(
#     final_loss_mean=('final_loss', 'mean'),
#     final_loss_std=('final_loss', 'std'),
#     eval_mean_error_max=('eval_mean_error_max', 'mean'),
#     eval_mean_error_max_std=('eval_mean_error_max', 'std'),
#     eval_max_error_mean=('eval_max_error_mean', 'mean'),
#     eval_max_error_max=('eval_max_error_max', 'max'),
#     wall_time_mean=('wall_time_s', 'mean'),
#     wall_time_std=('wall_time_s', 'std'),
# ).reset_index()
# agg_norbits

# %%
df['data.n_pts'] = df['data.n_orbits'] * df['data.n_steps']

# %% [markdown]
# # Training Evaluation
#
# How well did the models train?

# %%
# plot eval_mean_error_mean as a function of n_orbits, with a separate line for each n_steps
plt.figure(figsize=(7, 6))
for n_steps in df['data.n_steps'].unique():
    subset = df[df['data.n_steps'] == n_steps]
    plt.errorbar(subset['data.n_pts'], subset['tail_mean_loss'], yerr=subset['tail_std_loss'], marker='o', label=f'{n_steps} steps')
plt.xlabel('Number of Training Points', fontsize=20)
plt.ylabel('Final Loss', fontsize=20)
plt.yscale('log')
plt.xscale('log')
plt.legend(title='Points per Orbit')

# %%
# plot eval_mean_error_mean as a function of n_orbits, with a separate line for each n_steps
plt.figure(figsize=(7, 6))
for n_steps in df['data.n_steps'].unique():
    subset = df[df['data.n_steps'] == n_steps]
    plt.errorbar(subset['data.n_orbits'], subset['tail_mean_loss'], yerr=subset['tail_std_loss'], marker='o', label=f'{n_steps} steps')
plt.xlabel('Number of Orbits', fontsize=20)
plt.ylabel('Final Loss', fontsize=20)
plt.yscale('log')
plt.xscale('log')
plt.legend(title='Points per Training Orbit')

# %%
# plot eval_mean_error_mean as a function of n_orbits, with a separate line for each n_steps
plt.figure(figsize=(7, 6))
for n_steps in df['data.n_steps'].unique():
    subset = df[df['data.n_steps'] == n_steps]
    plt.errorbar(subset['data.n_orbits'], subset['tail_mean_loss']/subset['data.n_orbits'], yerr=subset['tail_std_loss']/subset['data.n_orbits'], marker='o', label=f'{n_steps} steps')
plt.xlabel('Number of Orbits', fontsize=20)
plt.ylabel('Final Loss / Number of Orbits', fontsize=20)
plt.yscale('log')
plt.xscale('log')
plt.legend(title='Points per Training Orbit')

# %%
# from mat
plt.figure(figsize=(7, 6))

for n_orbits in df['data.n_orbits'].unique():
    subset = df[df['data.n_orbits'] == n_orbits]
    for subset_id in subset['run_id']:
        filepath = Path('results') / 'runs'
        loss = np.load(filepath / subset_id / 'loss_curve.npy')
        plt.loglog(loss / n_orbits, lw=1, alpha=0.75)
    #plt.errorbar(subset['data.n_orbits'], subset['tail_mean_loss'], yerr=subset['tail_std_loss'], marker='o', label=f'{n_steps} steps')
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Loss / # of Orbits', fontsize=20)
plt.yscale('log')
plt.xscale('log')

# %%
plt.figure(figsize=(7, 6))

for n_orbits in df['data.n_orbits'].unique():
    subset = df[df['data.n_orbits'] == n_orbits]
    for subset_id in subset['run_id']:
        filepath = Path('results') / 'runs'
        lr = np.load(filepath / subset_id / 'lr_curve.npy')
        plt.loglog(lr, lw=1, alpha=0.75)
    #plt.errorbar(subset['data.n_orbits'], subset['tail_mean_loss'], yerr=subset['tail_std_loss'], marker='o', label=f'{n_steps} steps')
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Loss / # of Orbits', fontsize=20)
plt.yscale('log')
plt.xscale('log')

# %%
# filepath = Path('results') / 'runs'
# plt.figure(figsize=(8,6))
# for rundir in filepath.iterdir():
#     loss = np.load(rundir/'loss_curve.npy')
#     plt.loglog(loss)
# plt.xlabel('Epochs')
# plt.ylabel('Loss')

# %% [markdown]
# # Performance Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt

df_pivot = df.pivot(
    index='data.n_orbits',
    columns='data.n_steps',
    values='eval_max_error_mean'
)

x = df_pivot.columns.to_numpy()   # n_steps
y = df_pivot.index.to_numpy()     # n_orbits
z = np.log10(df_pivot.to_numpy())


x_plot = np.log2(x)
y_plot = np.log2(y)

fig, ax = plt.subplots(figsize=(7,7))

pcm = ax.pcolormesh(x_plot, y_plot, z, shading='auto', cmap='Purples_r')

ax.set_xticks(x_plot)
ax.set_xticklabels(x)

ax.set_yticks(y_plot)
ax.set_yticklabels(y)

ax.set_aspect('equal')

# Add text inside each cell
for i in range(len(y)):
    for j in range(len(x)):
        ax.text(
            x_plot[j],
            y_plot[i],
            f"{z[i, j]:.2f}",   # format to 2 decimals
            ha='center',
            va='center',
            fontsize=15
        )

fig.colorbar(pcm, label="$\\log_{10} \left ( \left \\langle \max_i \left ( \\frac{\Delta H}{\\langle H \\rangle_{i}} \\right ) \\right \\rangle_{j} \\right )$")

plt.xlabel("Points per Orbit", fontsize=20)
plt.ylabel("Number of Orbits", fontsize=20)
plt.title('Mean of Worst Errors along Orbits')
plt.show()
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\l'
# <>:42: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_318459/1595531374.py:42: SyntaxWarning: invalid escape sequence '\l'
#   fig.colorbar(pcm, label="$\\log_{10} \left ( \left \\langle \max_i \left ( \\frac{\Delta H}{\\langle H \\rangle_{i}} \\right ) \\right \\rangle_{j} \\right )$")

# %% [markdown]
# ### Worst Error of all points
#
# $i$ = index of point along an orbit
#
# $j$ = index of orbit

# %%
plt.figure(figsize=(7, 6))
for n_steps in df['data.n_orbits'].unique():
    subset = df[df['data.n_orbits'] == n_steps]
    plt.loglog(subset['data.n_steps'], subset['eval_max_error_max'], marker='o', label=f'{n_steps} Orbits')
plt.xlabel('Points Per Orbit', fontsize=20)
plt.ylabel('$\max_j \left ( \max_i \left (\\frac{\Delta H}{\\langle H \\rangle_i} \\right ) \\right )$', fontsize=25)
plt.legend(title='# of Orbits')
plt.title('Worst Error of All Points', fontsize=20)
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_318459/2451511125.py:6: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('$\max_j \left ( \max_i \left (\\frac{\Delta H}{\\langle H \\rangle_i} \\right ) \\right )$', fontsize=25)

# %% [markdown]
# ### Mean of the average error along orbits

# %%
plt.figure(figsize=(7, 6))
for n_steps in df['data.n_orbits'].unique():
    subset = df[df['data.n_orbits'] == n_steps]
    plt.loglog(subset['data.n_steps'], subset['eval_mean_error_mean'], marker='o', label=f'{n_steps} steps')
plt.xlabel('Points Per Orbit', fontsize=20)
plt.ylabel('$\left \\langle \left \\langle \\frac{\Delta H}{\\langle H \\rangle_{i}} \\right \\rangle_{i} \\right \\rangle_{j}$', fontsize=25)
plt.legend(title='# of Orbits')
plt.title('Mean of the Average Error Along Orbits', fontsize=20)
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_318459/3315183707.py:6: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\left \\langle \left \\langle \\frac{\Delta H}{\\langle H \\rangle_{i}} \\right \\rangle_{i} \\right \\rangle_{j}$', fontsize=25)

# %% [markdown]
# ## Mean of the worst errors along orbits

# %%
plt.figure(figsize=(7, 6))
for n_steps in df['data.n_orbits'].unique():
    subset = df[df['data.n_orbits'] == n_steps]
    plt.loglog(subset['data.n_steps'], subset['eval_max_error_mean'], marker='o', label=f'{n_steps} steps')
plt.xlabel('Points Per Orbit', fontsize=20)
plt.ylabel('$\left \\langle \max_i \left ( \\frac{\Delta H}{\\langle H \\rangle_{i}} \\right ) \\right \\rangle_{j}$', fontsize=25)
plt.legend(title='# of Orbits')
plt.title('Mean of the Worst Errors along Orbits', fontsize=20)
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_318459/1638837275.py:6: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\left \\langle \max_i \left ( \\frac{\Delta H}{\\langle H \\rangle_{i}} \\right ) \\right \\rangle_{j}$', fontsize=25)

# %% [markdown]
# ## Worst of the mean errors along orbits

# %%
plt.figure(figsize=(7, 6))
for n_steps in df['data.n_orbits'].unique():
    subset = df[df['data.n_orbits'] == n_steps]
    plt.loglog(subset['data.n_steps'], subset['eval_mean_error_max'], marker='o', label=f'{n_steps} steps')
plt.xlabel('Points per Orbit', fontsize=20)
plt.ylabel('$ \max_j \left ( \left \\langle \\frac{\Delta H}{\\langle H \\rangle_{i}} \\right \\rangle_{i} \\right )$', fontsize=25)
plt.legend(title='# of Orbits')
plt.title('Worst of the Mean Errors Along Orbits', fontsize=20)
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_318459/2079258067.py:6: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('$ \max_j \left ( \left \\langle \\frac{\Delta H}{\\langle H \\rangle_{i}} \\right \\rangle_{i} \\right )$', fontsize=25)
